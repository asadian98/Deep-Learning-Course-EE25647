# %% [markdown]
# <a href="https://colab.research.google.com/github/asadian98/Deep-Learning-Course-EE25647/blob/Preprocessing_ShowData/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In the name of God
#
# HW1, Computer Assignment, Question 1:
# **Hand Gestures Classification** (Tensorflow 1.x)

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd 'drive/MyDrive'

# %cd DL2122_HW01

# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/DL2122_HW01
# TensorFlow 1.x selected.
# 1.15.2

# %%
import pandas as pd
import io
import math
import matplotlib.pyplot as plt
import numpy as np

dftest = pd.read_csv('Q1_test.csv')
dftrain = pd.read_csv('Q1_train.csv')

y_training = dftrain.pop('label')
y_test = dftest.pop('label')

# %%
dftrain.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  ...  pixel781  pixel782  pixel783  pixel784
# 0     107     118     127     134  ...       206       204       203       202
# 1     155     157     156     156  ...       175       103       135       149
# 2     187     188     188     187  ...       198       195       194       195
# 3     211     211     212     212  ...       225       222       229       163
# 4     164     167     170     172  ...       157       163       164       179
#
# [5 rows x 784 columns]

# %%
dftrain.describe()
# Out:
#              pixel1        pixel2  ...      pixel783      pixel784
# count  27455.000000  27455.000000  ...  27455.000000  27455.000000
# mean     145.419377    148.500273  ...    161.137898    159.824731
# std       41.358555     39.942152  ...     63.610415     64.396846
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%      121.000000    126.000000  ...    128.000000    125.500000
# 50%      150.000000    153.000000  ...    182.000000    182.000000
# 75%      174.000000    176.000000  ...    204.000000    204.000000
# max      255.000000    255.000000  ...    255.000000    255.000000
#
# [8 rows x 784 columns]

# %%
print("train_images", dftrain.shape)
print("test_images", dftest.shape)
# Out:
# train_images (27455, 784)
# test_images (7172, 784)

# %%
y_training.hist(bins=25)

# %%
import string
picDict = dict((i, string.ascii_uppercase[i]) for i in range(25))

# %%
plt.imshow(dftrain.loc[1].values.reshape((28, 28)),cmap='gray')
plt.title(picDict[y_training[1]])
# Out:
# Text(0.5, 1.0, 'G')

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.imshow(dftrain.loc[i].values.reshape((28, 28)), cmap='gray')
  plt.title(picDict[y_training[i]])
  plt.xticks([])
  plt.yticks([])
  
plt.show()
